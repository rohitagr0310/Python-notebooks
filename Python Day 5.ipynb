# %% [markdown]
# Tuples
#
# syntax
# ```python
# tuple = (0,"hello", 3.14, False)
# ```

# %%
my_tuple = (0,"hello", 3.14, False)

# %%
months = ("January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December")

# %%
months[5]
# Out:
# 'June'

# %%
months[-1]
# Out:
# 'December'

# %%
for month in months:
    print(month)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
number = (1,2,3,4,5)

if 6 in number:
    print("3 is in the tuple")

# %%
months[::2]
# Out:
# ('January', 'March', 'May', 'July', 'September', 'November')

# %% [markdown]
# Lists
#
# syntax
# ```python
# my_list = [0, 3.14, False, "Hello"]
# ```

# %%
my_list = [0, 3.14, False, "Hello"]

# %%
my_list[0] = 1

# %%
my_list
# Out:
# [1, 3.14, False, 'Hello']

# %%
box = ["pencil", "pen", "scale"]

# %%
box.append("notebook")

# %%
box
# Out:
# ['pencil', 'pen', 'scale', 'notebook']

# %%
box.count("pencil")
# Out:
# 1

# %%
box.insert(0, "eraser")

# %%
box.pop(0)
# Out:
# 'notebook'

# %%
del box[0]

# %%
box
# Out:
# ['pen', 'pencil', 'eraser']

# %% [markdown]
# ```python
# dict = {"key1": "value1", "key2": "value2"}
# ```

# %%
student = {"name": "John", "age": 20, "grade": "A", "marks": [30,40,50]}

# %%
student["name"]
# Out:
# 'John'

# %%
student["marks"]
# Out:
# [30, 40, 50]

# %%
student.items()
# Out:
# dict_items([('name', 'John'), ('age', 20), ('grade', 'A'), ('marks', [30, 40, 50])])

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade', 'marks'])

# %%
student.values()
# Out:
# dict_values(['John', 20, 'A', [30, 40, 50]])

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name John
# age 20
# grade A
# marks [30, 40, 50]

# %%
student["marks"] = 10

# %%
student
# Out:
# {'name': 'John', 'age': 20, 'grade': 'A', 'marks': 10}

# %%
if student["marks"] > 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
marks = {"english": (45, 55)}

# %%
marks['english']
# Out:
# (45, 55)

# %%
a = [1,2,3]

a[1]= 5

# %%
a = [1,2,3]

new_list = [4,5,6]

a.extend(new_list)

# %%
a[0] = new_list[0]

# %%
a
# Out:
# [4, 2, 3, 4, 5, 6]

# %%
my_tuple = (0,1,2)

a , b, c = my_tuple[0], my_tuple[1], my_tuple[2]

# %%
a
# Out:
# 0

# %%
b
# Out:
# 1

# %%
a = [1,1,2]
a
# Out:
# [1, 1, 2]

# %%
a = (1,1,2)
a
# Out:
# (1, 1, 2)

# %% [markdown]
# # Assignments

# %% [markdown]
# ### **Tuples Assignments**

# %% [markdown]
# 1. Create a tuple of 10 random numbers. Write a program to:
#    - Print the sum of all numbers in the tuple.
#    - Print the maximum and minimum values from the tuple.

# %%
# Enter your code here

# %% [markdown]
# 2. Write a program that takes a tuple of names and prints only the names that are longer than 5 characters.

# %%
# Enter your code here

# %% [markdown]
# ### **Lists Assignments**

# %% [markdown]
# 1. Create a list of 10 integers. Write a program to:
#    - Print all even numbers from the list.
#    - Replace all odd numbers with `-1`.
#    - Reverse the list and print it.

# %%
# Enter your code here

# %% [markdown]
# 2. You have the following list of student marks:
#    ```python
#    marks = [55, 78, 89, 92, 45, 60]
#    ```
#    - Add 5 marks to each student.
#    - Remove all marks less than 60.
#    - Print the highest mark.

# %%
# Enter your code here

# %% [markdown]
# ### **Dictionaries Assignments**

# %% [markdown]
# 1. Create a dictionary of 5 employees with their salaries. Write a program to:
#    - Print the employee with the highest salary.
#    - Increase the salary of all employees by 10%.
#    - Remove an employee with a salary less than $5000.

# %%
# Enter your code here

# %% [markdown]
# 2. You have the following dictionary:
#    ```python
#    products = {"apple": 50, "banana": 20, "cherry": 75, "date": 40}
#    ```
#    - Add a new product "elderberry" with a price of 60.
#    - Write a program to print only the products that cost more than 50.
#    - Decrease the price of "banana" by 5 and update the dictionary.

# %%
# Enter your code here
