# %% [markdown]
# ```python
# for value in sequence:
#   # code block
# ```

# %%
for num in range(0, 6):
  print(num)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# break

# %%
for num in [1,3,4,5,2,7,8,9]:
  if num % 2 == 0:
    print(f"Even Number {num}")
    break
# Out:
# Even Number 4

# %%
names = ["rohit", "Ankit", "Raghav", "Nehal"]

count = 0
for name in names:
  print(name)
  count += 1
  if count == 2:
    break
# Out:
# rohit
# Ankit

# %% [markdown]
# continue

# %%
for num in range(10):
  if num % 2 == 0:
    continue
  print(num)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
names = ["Rohit", "Ankit", "Raghav", "Nehal"]

for name in names:
  if name.startswith("A"):
    continue
  print(name)
# Out:
# Rohit
# Raghav
# Nehal

# %% [markdown]
# ```python
# for outer in sequence1:
#   for inner in sequence2:
#     print(outer, inner)
# ```

# %%
for i in range(1, 4):
  for j in range(1, 4):
    print(f"{i} x {j} = {i * j}")
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9

# %%
for i in range(10):
  for j in range(10):
    print("#" ,end=" ")
  print()
# Out:
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #
# # # # # # # # # # #

# %%
list1 = [1, 2, "a", False, 3.44]
list2 = [3, 4]

list1[4]
# Out:
# 3.44

# %%
list1 = [1, 2, 5]
list2 = [3, 4]

for a in list1:
  for b in list2:
    print(a, b)
# Out:
# 1 3
# 1 4
# 2 3
# 2 4
# 5 3
# 5 4

# %%
age = 31

if age >= 18:
  print("You are eligible to vote")
  if age < 30:
    print("You are a young adult")
  else:
    print("you are an adult")
else:
  print("You are not eligible to vote")
# Out:
# You are eligible to vote
# you are an adult

# %%
num = 5

if num > 0:
  print("Positive")
elif num < 0:
  print("Negative")
else:
  print("Zero")
# Out:
# Positive

# %%
num = -5

if num >= 0:
  if num == 0:
    print("Zero")
  else:
    print("Positive")
else:
  print("Negative")
# Out:
# Negative

# %%
marks = 50

if marks >= 37:
  print("Pass")
  if marks >= 80:
    print("Grade A")
  elif marks >= 60:
    print("Grade B")
  elif marks >= 40:
    print("Grade C")
  else:
    print("Grade D")
else:
  print("Fail")
# Out:
# Pass
# Grade C

# %% [markdown]
# # Assignments

# %% [markdown]
# ### **Assignment 1: Advanced Loops**
# 1. **Topic**: Using `break`
#    - Write a program that stops when a number divisible by 5 is found in a range of numbers.

# %%
# Enter your code here

# %% [markdown]
# ### **Assignment 2: Advanced Loops**
# 1. **Topic**: Using `continue`
#    - Create a loop that skips all numbers greater than 10 in a list.

# %%
# Enter your code here

# %% [markdown]
# ### **Assignment 3: Advanced Loops**
# 1. **Topic**: Using `continue`
#    - Write a program that prints all names except those starting with the letter "B."

# %%
# Enter your code here

# %% [markdown]
# ### **Assignment 4: Nested Loops**
# 1. **Topic**: Nested Loops
#    - Write a program to print a rectangle of stars `*` with 4 rows and 5 columns.

# %%
# Enter your code here

# %% [markdown]
# ### **Assignment 5: Nested Conditional Statements**
# 1. **Topic**: Nested Conditional Statements
#    - Write a program to classify people as:
#      - "Child" if under 13
#      - "Teenager" if between 13 and 18
#      - "Adult" otherwise.

# %%
# Enter your code here

# %% [markdown]
# ### **Assignment 6: Nested Conditional Statements**
# 1. **Topic**: Nested Conditional Statements
#    - Write a program to determine the quadrant of a point `(x, y)` based on its coordinates:
#      - Quadrant 1: `x > 0` and `y > 0`
#      - Quadrant 2: `x < 0` and `y > 0`
#      - Quadrant 3: `x < 0` and `y < 0`
#      - Quadrant 4: `x > 0` and `y < 0`

# %%
# Enter your code here

# %%
number = 5

if number > 0:  # Check if the number is greater than zero
    print("Number is greater than zero.")

    if number == 0:  # Check if the number is equal to zero
        print("Number is also equal to zero.")
    else:
        print("Number is not zero.")
# Out:
# Number is greater than zero.
# Number is not zero.
